# %% [markdown]
# __<h1 style="text-align: center;font-size: 3rem">Data Rebalancing</h1><p style="text-align: center;font-size: 1.3rem">(Notebook III)</p>__

# %% [markdown]
# ## Imports
#
# Primarily importing from the `imblearn` module, using a mixture of over-sampling, under-sampling, and Imbalance-Learn's Pipeline which allows sampling methods to be mixed with SciKit-Learn's functionality.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import pandas as pd


from dotenv import load_dotenv
import os
from typing import NamedTuple

# %%
load_dotenv()
RANDOM_STATE = int(os.getenv("RANDOM_STATE", 0))

print(f"{RANDOM_STATE=}")
# Out:
# RANDOM_STATE=4813

# %%
def is_fraud(entries: pd.DataFrame) -> pd.Series:
    return entries["Class"] == 1

# %% [markdown]
# DataSplit will help organize between X and y

# %%
class FeatureTarget(NamedTuple):
    X: pd.DataFrame
    y: pd.Series

# %%
train_data = pd.read_parquet("../data/processed/train.parquet")

# %%
print(train_data["Class"].value_counts())
# Out:
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64

# %%
print(train_data["Class"].value_counts(normalize=True).apply(lambda x: f"{x:.2%}"))
# Out:
# Class
# 0    99.83%
# 1     0.17%
# Name: proportion, dtype: object

# %%
def boost_minority_by(target: pd.Series, proportion: float):
    if not 0 < proportion < 1:
        raise ValueError("Proportion must be between 0 and 1")
    class_counts = target.value_counts()

    return {
        i: int((1 + proportion) * count) if i == class_counts.idxmin() else count
        for i, count in class_counts.items()
    }

# %%
sm = SMOTE(
    sampling_strategy=boost_minority_by(is_fraud(train_data), 0.3),  # type: ignore (mypy)
    random_state=RANDOM_STATE,
)

# %%
rebal_train = pd.concat(
    sm.fit_resample(
        train_data.drop(columns=["Class"]),
        train_data["Class"],
    ),
    axis=1,
)

# %%
rebal_train.head(10)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  161919.0  1.946747 -0.752526 -1.355130 -0.661630  1.502822  4.024933
# 1  124477.0  2.035149 -0.048880 -3.058693  0.247945  2.943487  3.298697
# 2   41191.0 -0.991920  0.603193  0.711976 -0.992425 -0.825838  1.956261
# 3  132624.0  2.285718 -1.500239 -0.747565 -1.668119 -1.394143 -0.350339
# 4   59359.0 -0.448747 -1.011440  0.115903 -3.454854  0.715771 -0.147490
# 5   79404.0  1.320449 -1.560991 -0.154324 -1.806184 -0.831334  0.877820
# 6  111904.0  1.902180  0.158704 -0.210092  3.459251  0.346012  1.465813
# 7  151647.0  2.091991 -1.009477 -0.885660 -0.424255 -0.575602  0.486532
# 8  164062.0 -3.309691 -5.662946  0.466119 -0.430087  3.664003 -3.036146
# 9  148508.0  1.973973 -0.404605 -0.222072  0.534479 -0.830112 -0.626462
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0 -1.479661  1.139880  1.406819  ...  0.076197  0.297537  0.307915  0.690980
# 1 -0.002192  0.674782  0.045826  ...  0.038628  0.228197  0.035542  0.707090
# 2 -2.212603 -5.037523  0.000772  ... -2.798352  0.109526 -0.436530 -0.932803
# 3 -1.427984  0.010010 -1.118447  ... -0.139670  0.077013  0.208310 -0.538236
# 4  0.504347 -0.113817 -0.044782  ... -0.243245 -0.173298 -0.006692 -1.362383
# 5 -1.212515  0.246020 -1.747897  ... -0.346511 -0.941239 -0.104322 -1.790279
# 6 -0.749323  0.432622 -0.390130  ...  0.208545  0.646480  0.075336 -0.176780
# 7 -1.033124  0.201550  0.263308  ... -0.158022  0.244872  0.083967  0.116089
# 8 -2.841650  0.520501  1.485832  ...  0.819604  0.742448  1.745293 -0.490856
# 9 -0.595997 -0.066845  1.465829  ...  0.194876  0.822169  0.120061  0.072218
#
#         V25       V26       V27       V28  Amount  Class
# 0 -0.350316 -0.388907  0.077641 -0.032248    7.32      0
# 1  0.512885 -0.471198  0.002520 -0.069002    2.99      0
# 2  0.826684  0.913773  0.038049  0.185340  175.10      0
# 3 -0.278032 -0.162068  0.018045 -0.063005    6.10      0
# 4 -0.292234 -0.144622 -0.032580 -0.064194   86.10      0
# 5  0.184198 -0.299018  0.025862  0.016056  125.29      0
# 6 -0.095253  0.090097  0.004346 -0.045702    1.51      0
# 7  0.032727 -0.123307  0.042437 -0.051537   11.99      0
# 8 -2.153907  0.173475  0.119893  0.467544  208.60      0
# 9 -0.097635 -0.215837  0.041900 -0.036105    9.99      0
#
# [10 rows x 31 columns]

# %%
min_count = rebal_train[is_fraud(rebal_train)].shape[0]
min_count
# Out:
# 512

# %%
rus = RandomUnderSampler(
    sampling_strategy={0: int(min_count / 0.4), 1: min_count},  # type: ignore (mypy)
    random_state=RANDOM_STATE,
)

# %%
rebal_train = pd.concat(
    rus.fit_resample(
        rebal_train.drop(columns=["Class"]),
        rebal_train["Class"],
    ),
    axis=1,
)

# %%
rebal_train.value_counts("Class")
# Out:
# Class
# 0    1280
# 1     512
# Name: count, dtype: int64

# %%
pl = Pipeline(
    [
        ("smote", sm),
        ("under sample", rus),
    ],
    verbose=True,
)

# %%
train: FeatureTarget = FeatureTarget(
    X=train_data.drop(columns=["Class"]),
    y=train_data["Class"],
)

# %%
pl.fit_resample(train.X, train.y)
train.X.shape, train.y.shape
# Out:
# [Pipeline] ............. (step 1 of 2) Processing smote, total=   0.2s
# [Pipeline] ...... (step 2 of 2) Processing under sample, total=   0.0s
# ((227845, 30), (227845,))

# %%
train.X.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  161919.0  1.946747 -0.752526 -1.355130 -0.661630  1.502822  4.024933
# 1  124477.0  2.035149 -0.048880 -3.058693  0.247945  2.943487  3.298697
# 2   41191.0 -0.991920  0.603193  0.711976 -0.992425 -0.825838  1.956261
# 3  132624.0  2.285718 -1.500239 -0.747565 -1.668119 -1.394143 -0.350339
# 4   59359.0 -0.448747 -1.011440  0.115903 -3.454854  0.715771 -0.147490
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0 -1.479661  1.139880  1.406819  ... -0.134435  0.076197  0.297537  0.307915
# 1 -0.002192  0.674782  0.045826  ... -0.227279  0.038628  0.228197  0.035542
# 2 -2.212603 -5.037523  0.000772  ...  1.280856 -2.798352  0.109526 -0.436530
# 3 -1.427984  0.010010 -1.118447  ... -0.490642 -0.139670  0.077013  0.208310
# 4  0.504347 -0.113817 -0.044782  ... -0.275297 -0.243245 -0.173298 -0.006692
#
#         V24       V25       V26       V27       V28  Amount
# 0  0.690980 -0.350316 -0.388907  0.077641 -0.032248    7.32
# 1  0.707090  0.512885 -0.471198  0.002520 -0.069002    2.99
# 2 -0.932803  0.826684  0.913773  0.038049  0.185340  175.10
# 3 -0.538236 -0.278032 -0.162068  0.018045 -0.063005    6.10
# 4 -1.362383 -0.292234 -0.144622 -0.032580 -0.064194   86.10
#
# [5 rows x 30 columns]

# %%
train.y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64
